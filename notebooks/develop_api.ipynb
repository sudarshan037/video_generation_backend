# %%
import os
import json
import base64
import requests

if "notebooks" in os.getcwd():
    os.chdir("..")

# %%
import requests, json, base64

url = "http://127.0.0.1:8000/process/v1/image_to_video"
resp = requests.post(
    url,
    files={"image": open("data/test.webp", "rb")},
    data={"data": json.dumps({"prompt": "make video", "request_id": "test123"})},
)

result = resp.json()
result
# Out:
# {'request_id': 'test123', 'blob_path': 'data/generated_videos/test123.mp4'}

# %%
import requests, json, base64

url = "http://127.0.0.1:8000/process/v2/image_to_video"
resp = requests.post(
    url,
    files={"image": open("data/test.webp", "rb")},
    data={"data": json.dumps({"prompt": "make video", "request_id": "test123"})},
)

result = resp.json()
result
# Out:
# {'request_id': 'test123', 'blob_path': 'data/generated_videos/test123.mp4'}
